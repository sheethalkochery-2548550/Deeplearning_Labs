# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

# %%
with open("/content/dl_lab.txt", "r", encoding="utf-8") as file:
    text = file.read().lower()

# %%
# 2. Tokenization (word-level)
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
total_words = len(tokenizer.word_index) + 1

# %%
print("Total Vocabulary Size:", total_words)

print("\nFirst 20 words in vocabulary:")
for word, index in list(tokenizer.word_index.items())[:20]:
    print(word, ":", index)
# Out:
# Total Vocabulary Size: 183
#
# First 20 words in vocabulary:
# the : 1
# and : 2
# he : 3
# a : 4
# village : 5
# in : 6
# was : 7
# every : 8
# storyteller : 9
# of : 10
# about : 11
# him : 12
# arun : 13
# small : 14
# river : 15
# to : 16
# with : 17
# imagined : 18
# taught : 19
# brought : 20

# %%
print("\nSentence to Sequence Conversion:\n")

for sentence in text.split('.'):
    print("Sentence:", sentence.strip())
    print("Sequence:", tokenizer.texts_to_sequences([sentence])[0])
    print()
# Out:
# Sentence to Sequence Conversion:
#
# Sentence: once upon a time there was a small village near a quiet river
# Sequence: [21, 22, 4, 23, 24, 7, 4, 14, 5, 43, 4, 44, 15]
#
# Sentence: the village was surrounded by tall trees and green fields
# Sequence: [1, 5, 7, 45, 46, 47, 25, 2, 48, 26]
#
# Sentence: people in the village lived simple and peaceful lives
# Sequence: [27, 6, 1, 5, 28, 49, 2, 50, 51]
#
# Sentence: every morning the sun rose gently over the hills
# Sequence: [8, 52, 1, 53, 54, 55, 56, 1, 57]
#
# Sentence: the birds sang sweet songs in the early light
# Sequence: [1, 58, 59, 60, 61, 6, 1, 62, 63]
#
# Sentence: children walked together to the small village school
# Sequence: [29, 64, 65, 16, 1, 14, 5, 66]
#
# Sentence: farmers worked hard in their fields every day
# Sequence: [67, 68, 69, 6, 30, 26, 8, 70]
#
# Sentence: the river flowed calmly beside the village road
# Sequence: [1, 15, 71, 72, 73, 1, 5, 74]
#
# ...

# %%
# 3. Create Input Sequences
input_sequences = []
for line in text.split('\n'):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# Padding sequences
max_seq_len = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_seq_len, padding='pre')

# %%
# Split into predictors and label
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

y = to_categorical(y, num_classes=total_words)

# %%
rnn_model = Sequential()
rnn_model.add(Embedding(total_words, 100, input_length=max_seq_len-1))
rnn_model.add(SimpleRNN(150))
rnn_model.add(Dense(total_words, activation='softmax'))

rnn_model.compile(loss='categorical_crossentropy',
                  optimizer=Adam(learning_rate=0.001),
                  metrics=['accuracy'])

rnn_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
lstm_model = Sequential()
lstm_model.add(Embedding(total_words, 100, input_length=max_seq_len-1))
lstm_model.add(LSTM(150))
lstm_model.add(Dense(total_words, activation='softmax'))

lstm_model.compile(loss='categorical_crossentropy',
                   optimizer=Adam(learning_rate=0.001),
                   metrics=['accuracy'])

lstm_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
print("Training RNN...")
rnn_model.fit(X, y, epochs=50, verbose=1)

print("Training LSTM...")
lstm_model.fit(X, y, epochs=50, verbose=1)
# Out:
# Training RNN...
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.0281 - loss: 5.2014
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0491 - loss: 5.0560
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0679 - loss: 4.8861
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0538 - loss: 4.8107
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0785 - loss: 4.6529
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1154 - loss: 4.5515
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0865 - loss: 4.5097
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0916 - loss: 4.4406
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1435 - loss: 4.2291
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1736 - loss: 4.0546
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2154 - loss: 3.8973
# Epoch 12/50
# ...

# %%
def generate_text(seed_text, next_words, model):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_seq_len-1, padding='pre')

        predicted = np.argmax(model.predict(token_list, verbose=0), axis=-1)[0]

        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break

        seed_text += " " + output_word
    return seed_text

# %%
seed = "once upon a time"

print("\nRNN Generated Text:")
print(generate_text(seed, 10, rnn_model))

print("\nLSTM Generated Text:")
print(generate_text(seed, 10, lstm_model))
# Out:
# RNN Generated Text:
# once upon a time there was a small village near a quiet river flowed
#
# LSTM Generated Text:
# once upon a time there a a small village near a quiet river river

# %%
seed = "The river flowed calmly"

print("\nRNN Generated Text:")
print(generate_text(seed, 10, rnn_model))

print("\nLSTM Generated Text:")
print(generate_text(seed, 10, lstm_model))
# Out:
# RNN Generated Text:
# The river flowed calmly beside the village road simple street but special early green
#
# LSTM Generated Text:
# The river flowed calmly beside the village road road road road road green fields
